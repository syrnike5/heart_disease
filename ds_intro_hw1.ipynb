# %% [markdown]
# # 1. 주제 - 피마 인디언 당뇨병 데이터 분석
#
#
# # 2. 데이터 수집
#
# 데이터 수집 사이트 : https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database

# %% [markdown]
# # 3. feature 설명
#
# 1. Pregnancies: 임신 횟수
#
# 2. Glucose: 포도당 부하 검사 수치
#
# 3. BloodPressure: 혈압(mm Hg)
#
# 4. SkinThickness: 팔 삼두근 뒤쪽의 피하지방 측정값(mm)
#
# 5. Insulin: 혈청 인슐린(mu U/ml)
#
# 6. BMI: 체질량지수 (체중(kg) / 키(m)^2)
#
# 7. DiabetesPedigreeFunction: 당뇨 내력 가중치 값
#
# 8. Age: 나이
#
# 9. Outcome: 클래스 결정 값 (0 또는 1)

# %% [markdown]
# # 4. 과정
#
# 1. 데이터 탐색(차원, 기초 통계값, 결측치, 이상치)
# 2. 이상치 존재 -> 각 feature의 평균값을 넣는 이상치 처리 진행
# 3. 당뇨 양, 음성을 기준으로 다양한 통계값 확인
# 4. 나이를 기준으로 당뇨 양성자 분류
# 5. 데이터 정규화 후 거리, 코사인 유사도 계산
# 6. 공분산, 상관계수 계산

# %%
# 데이터 전처리에 필요한 라이브러리 임포트

import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
# 데이터 불러오기

df = pd.read_csv('/Users/yrlee/dgu_mac/1-2/데사개/ds_intro_hw1/diabetes.csv')

# %%
# 상위 5행 출력

df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 데이터 차원 확인

df.shape
# Out:
# (768, 9)

# %%
# 데이터 통계값 확인

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# 결측치 확인

df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# 이상치 개수 확인

zero_features = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

print("전체 데이터 {0}개 중" .format(df.shape[0]))

for i in zero_features:
    
    zero_count = df[df[i] == 0][i].count()
    ratio = (zero_count/df.shape[0]) * 100
    print("{0} feature에서 값이 0인 이상치의 개수는 {1}개, 비율은 {2:.2f}%입니다" .format(i, zero_count, ratio))
# Out:
# 전체 데이터 768개 중
# Glucose feature에서 값이 0인 이상치의 개수는 5개, 비율은 0.65%입니다
# BloodPressure feature에서 값이 0인 이상치의 개수는 35개, 비율은 4.56%입니다
# SkinThickness feature에서 값이 0인 이상치의 개수는 227개, 비율은 29.56%입니다
# Insulin feature에서 값이 0인 이상치의 개수는 374개, 비율은 48.70%입니다
# BMI feature에서 값이 0인 이상치의 개수는 11개, 비율은 1.43%입니다

# %%
# 각 feature에 평균값을 넣어 이상치 처리

for i in zero_features:
    df[i] = df[i].replace(0, df[i].mean())

# %%
# 인덱스 1부터 시작하게 맞추기

df.index = df.index + 1

# %%
# 열 이름 바꾸기

df = df.rename(columns = {'Outcome' : 'Diabetes'})

# %%
# 값 치환

df2 = df.copy()
df2['Diabetes'] = df2['Diabetes'].replace([0, 1], ["negative", "positive"])

# %%
# 데이터 확인

df2.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 1            6    148.0           72.0      35.000000   79.799479  33.6
# 2            1     85.0           66.0      29.000000   79.799479  26.6
# 3            8    183.0           64.0      20.536458   79.799479  23.3
# 4            1     89.0           66.0      23.000000   94.000000  28.1
# 5            0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Diabetes
# 1                     0.627   50  positive
# 2                     0.351   31  negative
# 3                     0.672   32  positive
# 4                     0.167   21  negative
# 5                     2.288   33  positive

# %%
# 고유값 확인

df2['Diabetes'].unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
# 음성, 양성 개수 확인

df2['Diabetes'].value_counts()
# Out:
# negative    500
# positive    268
# Name: Diabetes, dtype: int64

# %%
# 당뇨 양, 음성을 기준으로 최대값 계산

df2.groupby('Diabetes').max()
# Out:
#           Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Diabetes
# negative           13    197.0          122.0           60.0    744.0  57.3
# positive           17    199.0          114.0           99.0    846.0  67.1
#
#           DiabetesPedigreeFunction  Age
# Diabetes
# negative                     2.329   81
# positive                     2.420   70

# %%
# 당뇨 양, 음성을 기준으로 평균값 계산

df2.groupby('Diabetes').mean()
# Out:
#           Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Diabetes
# negative     3.298000  110.705367      70.810008      25.373135  106.457354
# positive     4.865672  142.159661      74.950326      28.907494  141.426597
#
#                 BMI  DiabetesPedigreeFunction        Age
# Diabetes
# negative  30.880066                  0.429734  31.190000
# positive  35.381288                  0.550500  37.067164

# %%
# 당뇨 양, 음성 칼럼으로 one-hot encoding 진행

dummy = pd.get_dummies(df2[['Diabetes']])
df3 = pd.concat([df2, dummy], axis = 1)

# %%
# 데이터 확인

df3.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 1            6    148.0           72.0      35.000000   79.799479  33.6
# 2            1     85.0           66.0      29.000000   79.799479  26.6
# 3            8    183.0           64.0      20.536458   79.799479  23.3
# 4            1     89.0           66.0      23.000000   94.000000  28.1
# 5            0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Diabetes  Diabetes_negative  \
# 1                     0.627   50  positive                  0
# 2                     0.351   31  negative                  1
# 3                     0.672   32  positive                  0
# 4                     0.167   21  negative                  1
# 5                     2.288   33  positive                  0
#
#    Diabetes_positive
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# 5                  1

# %%
# 이산화 진행

label = ['Children', 'Youth', 'Adults', 'Seniors']
df3['Age'] = pd.cut(x = df3['Age'], bins = [0, 14, 24, 64, 100], labels = label)
df3.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 1            6    148.0           72.0      35.000000   79.799479  33.6
# 2            1     85.0           66.0      29.000000   79.799479  26.6
# 3            8    183.0           64.0      20.536458   79.799479  23.3
# 4            1     89.0           66.0      23.000000   94.000000  28.1
# 5            0    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction     Age  Diabetes  Diabetes_negative  \
# 1                     0.627  Adults  positive                  0
# 2                     0.351  Adults  negative                  1
# 3                     0.672  Adults  positive                  0
# 4                     0.167   Youth  negative                  1
# 5                     2.288  Adults  positive                  0
#
#    Diabetes_positive
# 1                  1
# 2                  0
# 3                  1
# 4                  0
# 5                  1

# %%
# 나이를 기준으로 데이터 개수 카운팅

df3.groupby('Age')['Diabetes_positive'].count()
# Out:
# Age
# Children      0
# Youth       219
# Adults      533
# Seniors      16
# Name: Diabetes_positive, dtype: int64

# %%
# 나이를 기준으로 데이터 개수 카운팅

df3[df3['Diabetes_positive'] == 1].groupby('Age')['Diabetes_positive'].count()
# Out:
# Age
# Children      0
# Youth        31
# Adults      233
# Seniors       4
# Name: Diabetes_positive, dtype: int64

# %%
# 나이를 기준으로 당뇨 양성 비율 카운팅

for i in label:
    
    total = df3[(df3['Age'] == i)]['Age'].count()
    cnt = df3[(df3['Age'] == i) & (df3['Diabetes_positive'] == 1)]['Age'].count()
    ratio = (cnt / total) * 100
    
    if total == 0:
        ratio = 0
    
    print("{0} 카테고리의 전체 데이터 수는 {1}개, 양성 데이터 수는 {2}로 비율은 {3:3.2f}%입니다" .format(i, total, cnt, ratio))
# Out:
# Children 카테고리의 전체 데이터 수는 0개, 양성 데이터 수는 0로 비율은 0.00%입니다
# Youth 카테고리의 전체 데이터 수는 219개, 양성 데이터 수는 31로 비율은 14.16%입니다
# Adults 카테고리의 전체 데이터 수는 533개, 양성 데이터 수는 233로 비율은 43.71%입니다
# Seniors 카테고리의 전체 데이터 수는 16개, 양성 데이터 수는 4로 비율은 25.00%입니다
# /var/folders/df/1t_mj8rs75932mmcpnk3g9vh0000gn/T/ipykernel_25855/3979224928.py:7: RuntimeWarning: invalid value encountered in long_scalars
#   ratio = (cnt / total) * 100

# %%
# 데이터 정규화

df_normalization = (df - df.min()) / (df.max() - df.min())
df_normalization.head(5)
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 1     0.352941  0.670968       0.489796       0.304348  0.079086  0.314928
# 2     0.058824  0.264516       0.428571       0.239130  0.079086  0.171779
# 3     0.470588  0.896774       0.408163       0.147135  0.079086  0.104294
# 4     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 5     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Diabetes
# 1                  0.234415  0.483333       1.0
# 2                  0.116567  0.166667       0.0
# 3                  0.253629  0.183333       1.0
# 4                  0.038002  0.000000       0.0
# 5                  0.943638  0.200000       1.0

# %%
# 전체 데이터의 1차 거리 계산

total = 0
total_nor = 0
i = 0

while (i < 767):

    total += np.linalg.norm(df.iloc[i] - df.iloc[i+1], ord = 1)
    total_nor += np.linalg.norm(df_normalization.iloc[i] - df_normalization.iloc[i+1], ord = 1)
    i += 1
    
avg = total / 768
avg_nor = total_nor / 768
   
print("전체 데이터의 1차 거리는 {0:3.2f}이며, 정규화한 데이터의 1차 거리는 {1:3.2f}입니다." .format(avg, avg_nor))
# Out:
# 전체 데이터의 1차 거리는 156.59이며, 정규화한 데이터의 1차 거리는 1.72입니다.

# %%
# 전체 데이터의 2차 거리 계산

total = 0
total_nor = 0
i = 0

while (i < 767):

    total += np.linalg.norm(df.iloc[i] - df.iloc[i+1], ord = 2)
    total_nor += np.linalg.norm(df_normalization.iloc[i] - df_normalization.iloc[i+1], ord = 2)
    i += 1
    
avg = total / 768
avg_nor = total_nor / 768
   
print("전체 데이터의 2차 거리는 {0:3.2f}이며, 정규화한 데이터의 2차 거리는 {1:3.2f}입니다." .format(avg, avg_nor))
# Out:
# 전체 데이터의 2차 거리는 100.17이며, 정규화한 데이터의 2차 거리는 0.83입니다.

# %%
# 전체 데이터의 inf 거리 계산

total = 0
total_nor = 0
i = 0

while (i < 767):
     
    total += np.linalg.norm(df.iloc[i] - df.iloc[i+1], ord = np.inf)
    total_nor += np.linalg.norm(df_normalization.iloc[i] - df_normalization.iloc[i+1], ord = np.inf)
    i += 1
    
avg = total / 768
avg_nor = total_nor / 768
   
print("전체 데이터의 inf 거리는 {0:3.2f}이며, 정규화한 데이터의 inf 거리는 {1:3.2f}입니다." .format(avg, avg_nor))
# Out:
# 전체 데이터의 inf 거리는 89.96이며, 정규화한 데이터의 inf 거리는 0.65입니다.

# %%
# 기존 코사인 유사도 계산

cosine_similarity(np.array(df.iloc[0]).reshape(1, -1), np.array(df.iloc[767]).reshape(1, -1))
# Out:
# array([[0.97165855]])

# %%
# 정규화한 데이터의 코사인 유사도 계산

cosine_similarity(np.array(df_normalization.iloc[0]).reshape(1, -1), np.array(df_normalization.iloc[767]).reshape(1, -1))
# Out:
# array([[0.64007587]])

# %%
# 기존 데이터의 공분산 계산

df.cov()
# Out:
#                           Pregnancies      Glucose  BloodPressure  \
# Pregnancies                 11.354056    13.123525       8.531879
# Glucose                     13.123525   926.351048      81.004072
# BloodPressure                8.531879    81.004072     146.795798
# SkinThickness                0.434104    47.126333      15.654757
# Insulin                     -5.671349  1123.556474      12.322063
# BMI                          0.499157    48.438745      23.426997
# DiabetesPedigreeFunction    -0.037426     1.382625       0.001490
# Age                         21.570620    95.425324      46.555963
# Diabetes                     0.356618     7.155305       0.941851
#
#                           SkinThickness      Insulin         BMI  \
# Pregnancies                    0.434104    -5.671349    0.499157
# Glucose                       47.126333  1123.556474   48.438745
# BloodPressure                 15.654757    12.322063   23.426997
# SkinThickness                 92.760798   215.478568   35.473414
# Insulin                      215.478568  8663.952981  121.500481
# BMI                           35.473414   121.500481   47.270761
# DiabetesPedigreeFunction       0.494498     4.866760    0.349692
# Age                            2.992808    42.310463    2.081889
# Diabetes                       0.804005     7.954895    1.023950
#
#                           DiabetesPedigreeFunction         Age  Diabetes
# Pregnancies                              -0.037426   21.570620  0.356618
# Glucose                                   1.382625   95.425324  7.155305
# BloodPressure                             0.001490   46.555963  0.941851
# SkinThickness                             0.494498    2.992808  0.804005
# Insulin                                   4.866760   42.310463  7.954895
# BMI                                       0.349692    2.081889  1.023950
# DiabetesPedigreeFunction                  0.109779    0.130772  0.027472
# Age                                       0.130772  138.303046  1.336953
# Diabetes                                  0.027472    1.336953  0.227483

# %%
# 정규화한 데이터의 공분산 계산

df_normalization.cov()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  0.039287  0.004980       0.005121       0.000278
# Glucose                      0.004980  0.038558       0.005333       0.003305
# BloodPressure                0.005121  0.005333       0.015285       0.001736
# SkinThickness                0.000278  0.003305       0.001736       0.010959
# Insulin                     -0.000401  0.008712       0.000151       0.002815
# BMI                          0.000600  0.006391       0.004889       0.007885
# DiabetesPedigreeFunction    -0.000940  0.003809       0.000006       0.002295
# Age                          0.021148  0.010261       0.007918       0.000542
# Diabetes                     0.020978  0.046163       0.009611       0.008739
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.000401  0.000600                 -0.000940
# Glucose                   0.008712  0.006391                  0.003809
# BloodPressure             0.000151  0.004889                  0.000006
# SkinThickness             0.002815  0.007885                  0.002295
# Insulin                   0.012516  0.002986                  0.002498
# BMI                       0.002986  0.019769                  0.003053
# DiabetesPedigreeFunction  0.002498  0.003053                  0.020014
# Age                       0.000848  0.000710                  0.000931
# Diabetes                  0.009561  0.020940                  0.011730
#
#                                Age  Diabetes
# Pregnancies               0.021148  0.020978
# Glucose                   0.010261  0.046163
# BloodPressure             0.007918  0.009611
# SkinThickness             0.000542  0.008739
# Insulin                   0.000848  0.009561
# BMI                       0.000710  0.020940
# DiabetesPedigreeFunction  0.000931  0.011730
# Age                       0.038418  0.022283
# Diabetes                  0.022283  0.227483

# %%
# 기존 데이터의 상관계수 계산

co = df.corr()
co.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_dedf2_row0_col0, #T_dedf2_row1_col1, #T_dedf2_row2_col2, #T_dedf2_row3_col3, #T_dedf2_row4_col4, #T_dedf2_row5_col5, #T_dedf2_row6_col6, #T_dedf2_row7_col7, #T_dedf2_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dedf2_row0_col1, #T_dedf2_row0_col3, #T_dedf2_row0_col4, #T_dedf2_row0_col5, #T_dedf2_row0_col6, #T_dedf2_row2_col8, #T_dedf2_row3_col7, #T_dedf2_row5_col7, #T_dedf2_row6_col0, #T_dedf2_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dedf2_row0_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_dedf2_row0_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_dedf2_row0_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_dedf2_row1_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_dedf2_row1_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_dedf2_row1_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_dedf2_row1_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_dedf2_row1_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_dedf2_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_dedf2_row1_col7, #T_dedf2_row8_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_dedf2_row1_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_dedf2_row2_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_dedf2_row2_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_dedf2_row2_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_dedf2_row2_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_dedf2_row2_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_dedf2_row2_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_dedf2_row2_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_dedf2_row3_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_dedf2_row3_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_dedf2_row3_col2, #T_dedf2_row6_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_dedf2_row3_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_dedf2_row3_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_dedf2_row3_col6, #T_dedf2_row5_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_dedf2_row3_col8, #T_dedf2_row4_col0, #T_dedf2_row4_col7, #T_dedf2_row6_col8, #T_dedf2_row7_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_dedf2_row4_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_dedf2_row4_col2, #T_dedf2_row6_col1, #T_dedf2_row6_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_dedf2_row4_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_dedf2_row4_col5, #T_dedf2_row6_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_dedf2_row4_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_dedf2_row4_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_dedf2_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_dedf2_row5_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_dedf2_row5_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_dedf2_row5_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_dedf2_row5_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_dedf2_row5_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_dedf2_row6_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_dedf2_row7_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_dedf2_row7_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_dedf2_row7_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_dedf2_row7_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_dedf2_row7_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_dedf2_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_dedf2_row7_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_dedf2_row8_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_dedf2_row8_col2, #T_dedf2_row8_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_dedf2_row8_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_dedf2_row8_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_dedf2_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_dedf2_row8_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dedf2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dedf2_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_dedf2_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_dedf2_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_dedf2_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_dedf2_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_dedf2_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_dedf2_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_dedf2_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_dedf2_level0_col8" class="col_heading level0 col8" >Diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dedf2_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_dedf2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dedf2_row0_col1" class="data row0 col1" >0.127964</td>
#       <td id="T_dedf2_row0_col2" class="data row0 col2" >0.208984</td>
#       <td id="T_dedf2_row0_col3" class="data row0 col3" >0.013376</td>
#       <td id="T_dedf2_row0_col4" class="data row0 col4" >-0.018082</td>
#       <td id="T_dedf2_row0_col5" class="data row0 col5" >0.021546</td>
#       <td id="T_dedf2_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_dedf2_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_dedf2_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_dedf2_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_dedf2_row1_col0" class="data row1 col0" >0.127964</td>
#       <td id="T_dedf2_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dedf2_row1_col2" class="data row1 col2" >0.219666</td>
#       <td id="T_dedf2_row1_col3" class="data row1 col3" >0.160766</td>
#       <td id="T_dedf2_row1_col4" class="data row1 col4" >0.396597</td>
#       <td id="T_dedf2_row1_col5" class="data row1 col5" >0.231478</td>
#       <td id="T_dedf2_row1_col6" class="data row1 col6" >0.137106</td>
#       <td id="T_dedf2_row1_col7" class="data row1 col7" >0.266600</td>
#       <td id="T_dedf2_row1_col8" class="data row1 col8" >0.492908</td>
#     </tr>
#     <tr>
#       <th id="T_dedf2_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_dedf2_row2_col0" class="data row2 col0" >0.208984</td>
#       <td id="T_dedf2_row2_col1" class="data row2 col1" >0.219666</td>
#       <td id="T_dedf2_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_dedf2_row2_col3" class="data row2 col3" >0.134155</td>
#       <td id="T_dedf2_row2_col4" class="data row2 col4" >0.010926</td>
#       <td id="T_dedf2_row2_col5" class="data row2 col5" >0.281231</td>
#       <td id="T_dedf2_row2_col6" class="data row2 col6" >0.000371</td>
#       <td id="T_dedf2_row2_col7" class="data row2 col7" >0.326740</td>
#       <td id="T_dedf2_row2_col8" class="data row2 col8" >0.162986</td>
#     </tr>
#     <tr>
#       <th id="T_dedf2_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_dedf2_row3_col0" class="data row3 col0" >0.013376</td>
#       <td id="T_dedf2_row3_col1" class="data row3 col1" >0.160766</td>
#       <td id="T_dedf2_row3_col2" class="data row3 col2" >0.134155</td>
#       <td id="T_dedf2_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_dedf2_row3_col4" class="data row3 col4" >0.240361</td>
#       <td id="T_dedf2_row3_col5" class="data row3 col5" >0.535703</td>
#       <td id="T_dedf2_row3_col6" class="data row3 col6" >0.154961</td>

# %%
# 정규화한 데이터의 상관계수 계산

co2 = df_normalization.corr()
co2.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_be4dc_row0_col0, #T_be4dc_row1_col1, #T_be4dc_row2_col2, #T_be4dc_row3_col3, #T_be4dc_row4_col4, #T_be4dc_row5_col5, #T_be4dc_row6_col6, #T_be4dc_row7_col7, #T_be4dc_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_be4dc_row0_col1, #T_be4dc_row0_col3, #T_be4dc_row0_col4, #T_be4dc_row0_col5, #T_be4dc_row0_col6, #T_be4dc_row2_col8, #T_be4dc_row3_col7, #T_be4dc_row5_col7, #T_be4dc_row6_col0, #T_be4dc_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_be4dc_row0_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_be4dc_row0_col7 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_be4dc_row0_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_be4dc_row1_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_be4dc_row1_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_be4dc_row1_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_be4dc_row1_col4 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_be4dc_row1_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_be4dc_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_be4dc_row1_col7, #T_be4dc_row8_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_be4dc_row1_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_be4dc_row2_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_be4dc_row2_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_be4dc_row2_col3 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_be4dc_row2_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_be4dc_row2_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_be4dc_row2_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_be4dc_row2_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_be4dc_row3_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_be4dc_row3_col1 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_be4dc_row3_col2, #T_be4dc_row6_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_be4dc_row3_col4 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_be4dc_row3_col5 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_be4dc_row3_col6, #T_be4dc_row5_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_be4dc_row3_col8, #T_be4dc_row4_col0, #T_be4dc_row4_col7, #T_be4dc_row6_col8, #T_be4dc_row7_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_be4dc_row4_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_be4dc_row4_col2, #T_be4dc_row6_col1, #T_be4dc_row6_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_be4dc_row4_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_be4dc_row4_col5, #T_be4dc_row6_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_be4dc_row4_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_be4dc_row4_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_be4dc_row5_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_be4dc_row5_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_be4dc_row5_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_be4dc_row5_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_be4dc_row5_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_be4dc_row5_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_be4dc_row6_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_be4dc_row7_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_be4dc_row7_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_be4dc_row7_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_be4dc_row7_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_be4dc_row7_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_be4dc_row7_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_be4dc_row7_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_be4dc_row8_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_be4dc_row8_col2, #T_be4dc_row8_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_be4dc_row8_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_be4dc_row8_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_be4dc_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_be4dc_row8_col7 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_be4dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be4dc_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_be4dc_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_be4dc_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_be4dc_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_be4dc_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_be4dc_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_be4dc_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_be4dc_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_be4dc_level0_col8" class="col_heading level0 col8" >Diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be4dc_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_be4dc_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_be4dc_row0_col1" class="data row0 col1" >0.127964</td>
#       <td id="T_be4dc_row0_col2" class="data row0 col2" >0.208984</td>
#       <td id="T_be4dc_row0_col3" class="data row0 col3" >0.013376</td>
#       <td id="T_be4dc_row0_col4" class="data row0 col4" >-0.018082</td>
#       <td id="T_be4dc_row0_col5" class="data row0 col5" >0.021546</td>
#       <td id="T_be4dc_row0_col6" class="data row0 col6" >-0.033523</td>
#       <td id="T_be4dc_row0_col7" class="data row0 col7" >0.544341</td>
#       <td id="T_be4dc_row0_col8" class="data row0 col8" >0.221898</td>
#     </tr>
#     <tr>
#       <th id="T_be4dc_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_be4dc_row1_col0" class="data row1 col0" >0.127964</td>
#       <td id="T_be4dc_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_be4dc_row1_col2" class="data row1 col2" >0.219666</td>
#       <td id="T_be4dc_row1_col3" class="data row1 col3" >0.160766</td>
#       <td id="T_be4dc_row1_col4" class="data row1 col4" >0.396597</td>
#       <td id="T_be4dc_row1_col5" class="data row1 col5" >0.231478</td>
#       <td id="T_be4dc_row1_col6" class="data row1 col6" >0.137106</td>
#       <td id="T_be4dc_row1_col7" class="data row1 col7" >0.266600</td>
#       <td id="T_be4dc_row1_col8" class="data row1 col8" >0.492908</td>
#     </tr>
#     <tr>
#       <th id="T_be4dc_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_be4dc_row2_col0" class="data row2 col0" >0.208984</td>
#       <td id="T_be4dc_row2_col1" class="data row2 col1" >0.219666</td>
#       <td id="T_be4dc_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_be4dc_row2_col3" class="data row2 col3" >0.134155</td>
#       <td id="T_be4dc_row2_col4" class="data row2 col4" >0.010926</td>
#       <td id="T_be4dc_row2_col5" class="data row2 col5" >0.281231</td>
#       <td id="T_be4dc_row2_col6" class="data row2 col6" >0.000371</td>
#       <td id="T_be4dc_row2_col7" class="data row2 col7" >0.326740</td>
#       <td id="T_be4dc_row2_col8" class="data row2 col8" >0.162986</td>
#     </tr>
#     <tr>
#       <th id="T_be4dc_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_be4dc_row3_col0" class="data row3 col0" >0.013376</td>
#       <td id="T_be4dc_row3_col1" class="data row3 col1" >0.160766</td>
#       <td id="T_be4dc_row3_col2" class="data row3 col2" >0.134155</td>
#       <td id="T_be4dc_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_be4dc_row3_col4" class="data row3 col4" >0.240361</td>
#       <td id="T_be4dc_row3_col5" class="data row3 col5" >0.535703</td>
#       <td id="T_be4dc_row3_col6" class="data row3 col6" >0.154961</td>

# %% [markdown]
# # 5. 결론
#
# 1. 당뇨병 양성은 268개, 음성은 500개로 이루어진 데이터셋
# 2. 당뇨병 양성자의 평균 수치는 모든 feature에서 음성자의 평균 수치보다 높다.
# 3. Children 카테고리의 양성 비율은 0.00%, Youth 카테고리의 양성 비율은 14.16%, Adults 카테고리의 양성 비율은 43.71%, Seniors 카테고리의 양성 비율은 25.00%로 Adults 카테고리의 양성 비율이 제일 높다.
# 4. Minkowski 거리의 경우 차원이 커질수록 점점 0에 가까워지며 이는 데이터가 유사하다는 의미다.
# 5. 코사인 유사도는 정규화 전 데이터가 더욱 1에 가까운 수치가 나온다.
# 6. 기존 데이터와 정규화한 데이터의 공분산은 다르고 상관계수는 같다.
